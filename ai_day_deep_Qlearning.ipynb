# %% [markdown]
# # Install dependencies

# %%
# !apt-get install python-opengl -y

# !apt install xvfb -y

# !pip install pyvirtualdisplay

# !pip install piglet

# %% [markdown]
# # 1. Getting introduced to OpenAI GYM for reinforcement learning environments

# %% [markdown]
# The gym library is a collection of test problems — environments — that you can use to work out your reinforcement learning algorithms. These environments have a shared interface, allowing you to write general algorithms.

# %% [markdown]
# ## 1.1 Open AI gym interface

# %% [markdown]
# to create you custom environement following the gym interface you onl need to implement three methods, as the following:
# ```
# import gym
# class MyEnv(gym.Env):
#
#   def __init__():
#     super(MyEnv,self).__init()
#     self.action_space = # My action space
#     self.observation_space = # My observation space
#     pass
#
#   def setp(self,action):
#     # preform the a move
#     # output the next observation, the reward, done status, info dictionary
#     pass
#
#   def reset():
#     # initialize the environement
#     # return the inital observation
#     pass
#
#
#   def render():
#     # render the current state of the environment
#     pass
# ```
#
# As you have witnessed in the code above, you need also to specify the observation and the action space of your environement which are of type `Spaces`, and they describe the format of valid actions and observations:
#
# *   **Spaces.Box** : represents an n-dimensional box, so valid observations will be an array of N number
# *   **Spaces.Discrete**: representes a fixed range of non-negative numbers

# %% [markdown]
# ## 1.2 Open AI gym environements
#
# Open AI Gym provide us with a list of examples enivironemnts that we can use as a benchmark for our Rl Algorithms. the full list can be found at: https://gym.openai.com/envs.

# %%
from gym import envs
print(f"There are {len(envs.registry.all())} environement")
# Out:
# There are 859 environement

# %% [markdown]
# **For example: MountainCarm**
#
# A car is on a one-dimensional track, positioned between two "mountains". The goal is to drive up the mountain on the right; however, the car's engine is not strong enough to scale the mountain in a single pass. Therefore, the only way to succeed is to drive back and forth to build up momentum. Here, the reward is greater if you spend less energy to reach the goal

# %% [markdown]
# ![odrPU.gif](data:image/gif;base64,...)

# %% [markdown]
# ```
#     Description:
#         The agent (a car) is started at the bottom of a valley. For any given
#         state the agent may choose to accelerate to the left, right or cease
#         any acceleration.
#     Source:
#         The environment appeared first in Andrew Moore's PhD Thesis (1990).
#     Observation:
#         Type: Box(2)
#         Num    Observation               Min            Max
#         0      Car Position              -1.2           0.6
#         1      Car Velocity              -0.07          0.07
#     Actions:
#         Type: Discrete(3)
#         Num    Action
#         0      Accelerate to the Left
#         1      Don't accelerate
#         2      Accelerate to the Right
#         Note: This does not affect the amount of velocity affected by the
#         gravitational pull acting on the car.
#     Reward:
#          Reward of 0 is awarded if the agent reached the flag (position = 0.5)
#          on top of the mountain.
#          Reward of -1 is awarded if the position of the agent is less than 0.5.
#     Starting State:
#          The position of the car is assigned a uniform random value in
#          [-0.6 , -0.4].
#          The starting velocity of the car is always assigned to 0.
#     Episode Termination:
#          The car position is more than 0.5
#          Episode length is greater than 200
# ```

# %% [markdown]
# ### Mountain car with a discrete Action space

# %%
import gym


MountainCarDiscrete = gym.make("MountainCar-v0")

observation_space = MountainCarDiscrete.observation_space
action_space = MountainCarDiscrete.action_space

print(f"Observation space type: {type(observation_space)}")
print(f"High : {observation_space.high}")
print(f"Low : {observation_space.low}")
print()
print(f"Action space type: {type(action_space)}")
print(f"Number of actions: {action_space.n}")
# Out:
# Observation space type: <class 'gym.spaces.box.Box'>
# High : [0.6  0.07]
# Low : [-1.2  -0.07]
#
# Action space type: <class 'gym.spaces.discrete.Discrete'>
# Number of actions: 3

# %% [markdown]
# ### Mountain car with a continuous Action space

# %%
import gym


MountainCarContinuous = gym.make("MountainCarContinuous-v0")

observation_space = MountainCarContinuous.observation_space
action_space = MountainCarContinuous.action_space

print(f"Observation space type: {type(observation_space)}")
print(f"High : {observation_space.high}")
print(f"Low : {observation_space.low}")
print()
print(f"Action space type: {type(action_space)}")
print(f"High : {action_space.high}")
print(f"Low : {action_space.low}")
# Out:
# Observation space type: <class 'gym.spaces.box.Box'>
# High : [0.6  0.07]
# Low : [-1.2  -0.07]
#
# Action space type: <class 'gym.spaces.box.Box'>
# High : [1.]
# Low : [-1.]

# %% [markdown]
# # 2. Q-learning Algorithm (High level explanation)

# %% [markdown]
# ## 2.1 The algorithm of Q-learning

# %% [markdown]
# *  Q-learning is an off policy reinforcement learning algorithm that seeks to find the best action to take given the current state.
#
# *   Q-learning tries to find an optimal policy by finding a good estimate of the Action value function Q ( called the Q function)
#
#
# *   Q(S,a) express how good is to take action `a` at state `S`
#
# *   Q-learning Algorithm stores a refrence to a state/action table that associate each (state/action) pair to his Q function value
#
# *   Q-learning Algorithms iterativley update this table until reaching a table state that satisfy using the bellman equation

# %% [markdown]
# ![Screen Shot 2021-02-04 at 00.18.09.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-02-04 at 00.44.27.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.2 Demo of Q-learning Algorithm

# %% [markdown]
# ![ezgif.com-gif-maker.gif](data:image/gif;base64,...)

# %% [markdown]
# # 3.Deep Q-learning (Tensorflow and pytorch)

# %% [markdown]
# ## 3.1 Deep Q-learning Algorithm

# %% [markdown]
# ![Screenshot-2019-04-16-at-5.46.01-PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Algorithm steps

# %% [markdown]
# All the past experience is stored by the user in memory
# The next action is determined by the maximum output of the Q-network
# The loss function here is mean squared error of the predicted Q-value and the target Q-value – Q*. This is basically a regression problem. However, we do not know the target or actual value here as we are dealing with a reinforcement learning problem. Going back to the Q-value update equation derived fromthe Bellman equation. we have:
#
#
#
# 1.   All the past experience is stored by the user in memory
# 2.   The next action is determined by the maximum output of the Q-network
# 3.   The loss function here is mean squared error of the predicted Q-value and the target Q-value – Q*.
#
#
#
# This is basically a regression problem. However, we do not know the target or actual value here as we are dealing with a reinforcement learning problem.

# %% [markdown]
# ### Problems and solutions

# %% [markdown]
# #### 1. We are chasing a moving target

# %% [markdown]
# ![Screen Shot 2021-02-06 at 11.30.19.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-02-06 at 11.32.21.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-02-06 at 11.35.39.png](data:image/png;base64,...)

# %% [markdown]
# #### 2. Exploration vs Exploitation

# %% [markdown]
# ![Screen Shot 2021-02-06 at 11.44.18.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot-2020-03-18-at-8.03.38-PM.png](data:image/png;base64,...)

# %% [markdown]
# #### Workshop

# %% [markdown]
# **CartPole** : a pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The system is controlled by applying a force of +1 or -1 to the cart. The pendulum starts upright, and the goal is to prevent it from falling over. A reward of +1 is provided for every timestep that the pole remains upright. The episode ends when the pole is more than 15 degrees from vertical, or the cart moves more than 2.4 units from the center.

# %% [markdown]
# ![title.gif](data:image/gif;base64,...)

# %%
import gym


env = gym.make("CartPole-v0")

state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %% [markdown]
# ## 3.2 Watch a random agent

# %% [markdown]
# run inference using a random agent across multiple episodes

# %%
from pyvirtualdisplay import Display
Display().start()


from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline
import time 

num_episodes = 1
rewards = []
random_agent_avg_reward_progress = []

for episode in range(num_episodes): 

  state = env.reset()
  img = plt.imshow(env.render('rgb_array')) # only call this once
  is_episode_done = False
  total_reward = 0
  step = 0
  

  while not is_episode_done: 
    step += 1

    #################### Graphics ###################################/
    img.set_data(env.render('rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    ###############################################################/

    random_action = env.action_space.sample()
    state, reward, is_episode_done, _ = env.step(random_action)
    total_reward += reward
  
  print(f"Episode {episode + 1} / reward  {total_reward} / steps {step}")

  rewards.append(total_reward)
  avg_reward = sum(rewards)/len(rewards)
  random_agent_avg_reward_progress.append(avg_reward)
# Out:
# Episode 1 / reward  17.0 / steps 17

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from collections import deque

def dqn(agent, n_episodes=5000, max_t=1000, eps_start=1.0, eps_end=0.001, eps_decay=0.995):
    """
    Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """

    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    strike = 0

    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        score = 0

        for t in range(max_t):
            action = agent.act(np.asarray(state), eps)            
            next_state, reward, done, _ = env.step(action)
            agent.step(state, action, reward, next_state, done)
            
            state = next_state
            score += reward
            
            if done:
                break 
                
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon

        avg_reward = np.mean(scores_window)

        strike+= 1 if avg_reward > 195.0 else -strike

        if strike >= 100: 
            print('Env solved in {} Episodes \tAverage Score: {:.2f}'.format(i_episode,avg_reward))
            break

        if i_episode % 100 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, avg_reward))
            
    return scores

# %%
class Agent():
    """Interacts with and learns from the environment."""

    def step(self, state, action, reward, next_state, done):
        pass

    def act(self, state, eps=0.):
        pass

    def learn(self, experiences, gamma):
        pass

# %% [markdown]
# ## 3.3 Deep Q-learning with Tensorflow Keras API

# %%
import tensorflow as tf
import numpy as np 
from collections import namedtuple, deque
import random

tfk = tf.keras
tfkl = tf.keras.layers

# %%
BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 64         # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR = 5e-4               # learning rate
UPDATE_EVERY = 10       # how often to update the network

# %%
def qnetwork_factory(state_size,action_size): 

    dense_units = [64,64]

    input = tfkl.Input(shape=(state_size,))
    x = input 

    for units in dense_units: 
      x = tfkl.Dense(units,activation="relu")(x)

    output = tfkl.Dense(action_size)(x)

    return tfk.Model(inputs=input,outputs=output)

# %%
class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            seed (int): random seed
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
        
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = tf.constant(np.vstack([e.state for e in experiences if e is not None]), dtype=tf.float32)
        actions = tf.constant(np.vstack([e.action for e in experiences if e is not None]), dtype=tf.float32)
        rewards = tf.constant(np.vstack([e.reward for e in experiences if e is not None]), dtype=tf.float32)
        next_states = tf.constant(np.vstack([e.next_state for e in experiences if e is not None]), dtype=tf.float32)
        dones = tf.constant(np.vstack([e.done for e in experiences if e is not None]), dtype=tf.float32)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
class TFAgent:


  def __init__(self, state_size,action_size, seed=0):
    
    """
    Initialize an Agent object.
    Params
    ======
        state_size (int): dimension of each state
        action_size (int): dimension of each action
        seed (int): random seed
    """

    self.state_size = state_size 
    self.action_size = action_size
    self.seed = random.seed(seed)


    self.qnetwork_local = qnetwork_factory(state_size,action_size)
    self.qnetwork_target = qnetwork_factory(state_size,action_size)
    
    self.optimizer = tfk.optimizers.Adam(learning_rate=LR)

    self.memory = ReplayBuffer(action_size, BUFFER_SIZE,BATCH_SIZE, seed)
    # Initialize time step (for updating every UPDATE_EVERY steps)
    self.training_step = 0
  
  def step(self, state, action, reward, next_state, done):

    # Sace experince in replay memory 
    self.memory.add(state,action,reward,next_state,done)
    self.training_step = (self.training_step +1) % UPDATE_EVERY

    if self.training_step == 0: 
       # If enough samples are available in memory, get random subset and learn
       if len(self.memory) > BATCH_SIZE:
         experiences = self.memory.sample()
         self.learn(experiences, GAMMA)
  
  def act(self, state, eps=0.):
    """
        Returns actions for given state as per current policy.
        Params
        ======
            state (array_like): current state
            eps (float): epsilon, for epsilon-greedy action selection
    """
    # Epsilon-greedy action selection, this is why Q-learning is called off-policy: training policy is diffrent than inference policy
    if random.random() > eps:
        state = tf.constant(state, dtype= tf.float32) # (state_size,)
        batched_state = tf.expand_dims(state, axis=0) # (1,state_size)
        batched_qvalues = self.qnetwork_local(batched_state, training=False)  # (1,action_size)
        qvalues = tf.squeeze(batched_qvalues) # (action_size,)
        return np.argmax(qvalues.numpy())  # (1,)
    else:
        return random.choice(np.arange(self.action_size))

  def learn(self,experiences,gamma):
    """
    Update value parameters using given batch of experience tuples.
    Params
    ======
        experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples
        gamma (float): discount factor
    """
    states, actions, rewards, next_states, dones = experiences

    # watch only the local network variables
    with tf.GradientTape(watch_accessed_variables=False) as tape: 
      
      tape.watch(self.qnetwork_local.trainable_weights)

      q_next = self.qnetwork_target(next_states) # ( batch_size, action_size)
      q_targets_next = tf.math.reduce_max(q_next, axis=1,keepdims=True)  # ( batch_size,1)
      
      # Compute Q targets for current states
      q_targets = rewards + (gamma * q_targets_next * (1 - dones)) # ( batch_size,1)

      # Get expected Q values from local model
      q_current = self.qnetwork_local(states) # ( batch_size, action_size)

      # get the values action with max Q
      actions_indexes = tf.cast(actions, dtype=tf.int32)  # ( batch_size, 1)
      q_expected = tf.gather_nd(q_current, actions_indexes, batch_dims=1)  # ( batch_size,)
      q_expected =  tf.expand_dims(q_expected, axis=1) # ( batch_size,1)

 
      # calculate the mean squared error loss
      loss = tfk.losses.MSE(q_targets,q_expected)

      # calculate the gradient
      gradients = tape.gradient(loss, self.qnetwork_local.trainable_weights)

      # do a backprob and update the local network
      self.optimizer.apply_gradients(zip(gradients, self.qnetwork_local.trainable_weights))

    self.soft_update()

  def soft_update(self):
    "softly update the target network"
    local_weights = self.qnetwork_local.get_weights()
    target_weights = self.qnetwork_target.get_weights()
    counter = 0
    for q_weight, target_weight in zip(local_weights,target_weights):
        target_weight = target_weight * (1-TAU) + q_weight * TAU
        target_weights[counter] = target_weight
        counter += 1
    self.qnetwork_target.set_weights(target_weights)

# %%
tf_agent = TFAgent(state_size=state_size, action_size=action_size)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

scores = dqn(tf_agent)

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 100	Average Score: 18.49
# Episode 200	Average Score: 12.34
# Episode 300	Average Score: 10.52
# Episode 400	Average Score: 10.13
# Episode 500	Average Score: 9.88
# Episode 600	Average Score: 9.50
# Episode 700	Average Score: 9.51
# Episode 800	Average Score: 9.60
# Episode 900	Average Score: 9.26
# Episode 1000	Average Score: 9.31
# Episode 1100	Average Score: 9.43
# Episode 1200	Average Score: 9.34
# Episode 1300	Average Score: 9.32
# Episode 1400	Average Score: 9.28
# Episode 1500	Average Score: 9.28
# Episode 1600	Average Score: 9.25
# Episode 1700	Average Score: 9.25
# Episode 1800	Average Score: 9.39
# Episode 1900	Average Score: 9.29
# Episode 2000	Average Score: 9.24
# Episode 2100	Average Score: 9.42
# Episode 2200	Average Score: 9.43
# Episode 2300	Average Score: 9.30
# Episode 2400	Average Score: 9.81
# Episode 2500	Average Score: 9.48
# Episode 2600	Average Score: 9.48
# Episode 2700	Average Score: 9.52
# Episode 2800	Average Score: 9.38
# ...

# %% [markdown]
# ## 3.4 Deep Q-learning with Pytorch

# %%
import numpy as np
import random
from collections import namedtuple, deque

import torch
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 64         # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR = 5e-4               # learning rate
UPDATE_EVERY = 10       # how often to update the network

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class QNetwork(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, fc1_units=64, fc2_units=64):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)

    def forward(self, state):
        """Build a network that maps state -> action values."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %%
class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            seed (int): random seed
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)

    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(
            device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(
            device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
class TrochAgent(Agent):
    """Interacts with and learns from the environment."""

    def __init__(self, state_size, action_size, seed=0):
        """Initialize an Agent object.
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)

        # Q-Network
        self.qnetwork_local = QNetwork(state_size, action_size, seed).to(device)
        self.qnetwork_target = QNetwork(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=LR)

        # Replay memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        # Initialize time step (for updating every UPDATE_EVERY steps)
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        self.memory.add(state, action, reward, next_state, done)

        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > BATCH_SIZE:
                experiences = self.memory.sample()
                self.learn(experiences, GAMMA)

    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy.
        Params
        ======
            state (array_like): current state
            eps (float): epsilon, for epsilon-greedy action selection
        """
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state)
        self.qnetwork_local.train()

        # Epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples.
        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # Get max predicted Q values (for next states) from target model
        Q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
        # Compute Q targets for current states
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))

        # Get expected Q values from local model
        Q_expected = self.qnetwork_local(states).gather(1, actions)

        # Compute loss
        loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # ------------------- update target network ------------------- #
        self.soft_update(self.qnetwork_local, self.qnetwork_target, TAU)

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Params
        ======
            local_model (PyTorch model): weights will be copied from
            target_model (PyTorch model): weights will be copied to
            tau (float): interpolation parameter
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

# %%
torch_agent = TrochAgent(state_size=state_size, action_size=action_size)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

scores = dqn(torch_agent)

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 100	Average Score: 17.21
# Episode 200	Average Score: 12.51
# Episode 300	Average Score: 10.56
# Episode 400	Average Score: 10.09
# Episode 500	Average Score: 9.82
# Episode 600	Average Score: 9.50
# Episode 700	Average Score: 9.90
# Episode 800	Average Score: 9.67
# Episode 900	Average Score: 9.51
# Episode 1000	Average Score: 9.43
# Episode 1100	Average Score: 9.57
# Episode 1200	Average Score: 9.44
# Episode 1300	Average Score: 9.32
# Episode 1400	Average Score: 9.30
# Episode 1500	Average Score: 9.41
# Episode 1600	Average Score: 9.27
# Episode 1700	Average Score: 9.41
# Episode 1800	Average Score: 9.55
# Episode 1900	Average Score: 10.53
# Episode 2000	Average Score: 9.43
# Episode 2100	Average Score: 11.19
# Episode 2200	Average Score: 11.20
# Episode 2300	Average Score: 11.03
# Episode 2400	Average Score: 11.51
# Episode 2500	Average Score: 13.21
# Episode 2600	Average Score: 14.54
# Episode 2700	Average Score: 14.31
# Episode 2800	Average Score: 16.35
# ...

# %% [markdown]
# ## 3.5 Watch a trained agent

# %%
from pyvirtualdisplay import Display
Display().start()


from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline
import time 

num_episodes = 10
rewards = []
random_agent_avg_reward_progress = []

for episode in range(num_episodes): 

  state = env.reset()
  img = plt.imshow(env.render('rgb_array')) # only call this once
  is_episode_done = False
  total_reward = 0
  step = 0
  

  while not is_episode_done: 
    step += 1

    #################### Graphics ###################################/
    img.set_data(env.render('rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    ###############################################################/

    action = tf_agent.act(state)
    state, reward, is_episode_done, _ = env.step(action)
    total_reward += reward
  
  print(f"Episode {episode + 1} / reward  {total_reward} / steps {step}")

  rewards.append(total_reward)
  avg_reward = sum(rewards)/len(rewards)
  random_agent_avg_reward_progress.append(avg_reward)
# Out:
# Episode 1 / reward  200.0 / steps 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-746e71ad0a38> in <module>()
#      26     #################### Graphics ###################################/
#      27     img.set_data(env.render('rgb_array')) # just update the data
# ---> 28     display.display(plt.gcf())
#      29     display.clear_output(wait=True)
#      30     ###############################################################/
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ...

# %%
from pyvirtualdisplay import Display
Display().start()


from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline
import time 

num_episodes = 1
rewards = []
random_agent_avg_reward_progress = []

for episode in range(num_episodes): 

  state = env.reset()
  img = plt.imshow(env.render('rgb_array')) # only call this once
  is_episode_done = False
  total_reward = 0
  step = 0
  

  while not is_episode_done: 
    step += 1

    #################### Graphics ###################################/
    img.set_data(env.render('rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    ###############################################################/

    action = tf_agent.act(state)
    state, reward, is_episode_done, _ = env.step(action)
    total_reward += reward
  
  print(f"Episode {episode + 1} / reward  {total_reward} / steps {step}")

  rewards.append(total_reward)
  avg_reward = sum(rewards)/len(rewards)
  random_agent_avg_reward_progress.append(avg_reward)
# Out:
# Episode 1 / reward  200.0 / steps 200
# Episode 2 / reward  200.0 / steps 200
# Episode 3 / reward  200.0 / steps 200
# Episode 4 / reward  200.0 / steps 200
# Episode 5 / reward  200.0 / steps 200
# Episode 6 / reward  200.0 / steps 200
# Episode 7 / reward  200.0 / steps 200
# Episode 8 / reward  200.0 / steps 200
# Episode 9 / reward  200.0 / steps 200
# Episode 10 / reward  200.0 / steps 200
